# %% [markdown]
# ## Python refreshers

# %%
# basics of python ->
# interpreter/ compiler
# what are the use cases -> for placement Backend develpment, Data science, Machine Learning/ AI , automation
# how its diffrent other languages -> easy to read/ write

# %% [markdown]
# ## Data type

# %%
# basic datatypes
# str, int, bool , float, None
# str num = 'hello'
num = 'hello'
print(type(num))

# iterables
# list, tuple , and dict
l = []

# %% [markdown]
# # conditional loop and if else

# %%
# if , else, elif

# %% [markdown]
# # functions

# %%
# parameters , arguments , key_word arguments return

def function_name(a, b):
    return a+b
# Out:
#   File "<ipython-input-12-e6053ddf76cd>", line 5
#     int function_name(int a, int b)
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# Application-based Numpy and Pandas

# %%
import numpy as np # freatueres of numpy , usecases
import pandas as pd #features of pandas , usecases

# %% [markdown]
# # Lifecycle of ML Project

# %%
# step1 -> define the problem /set objective
# step2 -> collect data
# step3 -> preprocessing
# step4 -> mode selection
# step5 -> model triaing
# step6 -> model evalutaion
# step7 -> production
# Out:
#   File "<ipython-input-10-2b928cb0aeb2>", line 1
#     step1 -> define the problem /set objective
#           ^
# SyntaxError: invalid syntax

# %%
# printing statments in pyhton
# print statement is used to print something
print("Hello world")
# Out:
# Hello world

# %%
# taking input from user and then printing that input
user_input = input()
print(user_input)
# Out:
# helllo world
# helllo world

# %%
# operator operation
# there are multiple operators +, -, *, /, // floor division
a = 1
b = 2
sum_a_b = a + b
diff_a_b = a - b
multi_a_b = a*b
div = a/ b
intdivision = a//b # gives int part only

# %% [markdown]
# ## if else

# %%
if condition1: # checks if condition1 is true if consdition1 code gets executed
    condition1 code
elif condition2: # if condition 1 is false then only this condition get checked and if this condition is true then codeition2 code runs
    condition2
else: # if none of above conditions are true
    do this
# Out:
#   File "<ipython-input-19-8496403365d8>", line 1
#     if condition:
#                  ^
# SyntaxError: incomplete input

# %%
# dynamic types variable
# case sensitive
# starts with either char, or underscore

a = 'aaaa' # string , immutalble
# variable[1]='c'
print(type(variable))


_variable = 3/2 # converted to int
print(type(_variable))
A = 'aaaaaa'

print(A, a)
# Out:
# <class 'float'>
# <class 'float'>
# aaaaaa aaaa

# %%
# operatros
# +, -, *, / , %

# //
a = 3/2 # float
A = 3//2 # float int part

# ** power
a = 2**3
print(a)

# &, |, >>, << , ^ , !, ~

# conditional
# && -> and (1&&0) (1 and 0 )
# || -> or

# if(a&&b) = > if (a and b)
# if(a||b) => if (a or b )
# Out:
# 8

# %%
# list , tuple , dict

# list -> similar to array , used to store collection of items (can be of diffrent datatypes)
l = [1,'a',3,'b','abdg',True,7,['a', 'jhf' ] ]
# t = (1, 2,4, 'a')

# %%
l[0]= 'abd'
print(l)
# Out:
# ['abd', 'a', 3, 'b', 'abdg', True, 7, ['a', 'jhf']]

# %%
condition = True

# if condition:
#     # this is startinf acope if
#     print(1)
#     print(2)
#     print(3)
#     print('This is else', a, condition)
# elif constion2:
#     print(2)


# multiple conditions
marks1 = 91
# else "Fail"

if marks1>90:
    print("A")
else:
    print('Fail')

# print(4)
# Out:
# A

# %%
a =1
b = 0

if a>0:
    if b>0:
        print('Yes')
    else:
        print('NO')
else:
    print('NO')
# Out:
# NO

# %%
# and, or
if (a>0 and b>0): # b>0 false
    print('Yes')
else:
    print('No')
# Out:
# No

# %%
i = 0
while (i<10):
    print(i)
    i=i+1
print('end while ')
while condition:
    execute this
    change_condition
# Out:
#   File "<ipython-input-52-65babe0b434e>", line 7
#     execute this
#             ^
# SyntaxError: invalid syntax

# %%
def addtion(a, b):
    c = a+b
    # print(c)
    return c

def subtaction(a, b):
    c = a-b
    return c

a_ = 2
b_ = 5
d = addtion(a_,b_)
e = subtaction(a_,b_)
print(d,e)
# Out:
# 7 -3

# %%
a = []
i = 0
while i<10:
    a.append(i)
    i+=1
